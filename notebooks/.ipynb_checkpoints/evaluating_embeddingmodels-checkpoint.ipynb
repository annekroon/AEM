# %% [markdown]
# # Evaluating embedding models
#
# Evaluating the accuracy of w2v models.
# See https://arxiv.org/pdf/1801.09536.pdf and http://www.aclweb.org/anthology/D15-1036
#
# useful tutorial:
# https://github.com/parulsethi/gensim/blob/wordrank_wrapper/docs/notebooks/Wordrank_comparisons.ipynb

# %%
import gensim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gensim.models import FastText
from gensim.models import KeyedVectors

from sklearn.manifold import TSNE

# %%
models = "../../models/"
word_analogies_file = "../model_evaluation/analogies/questions.txt"
wiki_model = '/Volumes/AnneKroon/'
similarity_file = '../model_evaluation/similarities/wordsim353/wordsim353_nl_kort.tsv'

# %% [markdown]
# ### Load pre-trained embedding model (LN - newspaper data)

# %%
print('\nLoading Gensim embeddings')
w2v_np = gensim.models.Word2Vec.load(models + 'W2V') # this is trained on VK, Tel, AD, Trouw, NRC 2000-01-01 - 2015-12-31
# Out:
# 2019-01-07 14:26:09,017 : INFO : loading Word2Vec object from /Users/admin/gitprojects/trained_data/all/W2V
# Loading Gensim embeddings
# 2019-01-07 14:26:23,308 : INFO : loaded /Users/admin/gitprojects/trained_data/all/W2V
# 2019-01-07 14:26:23,344 : INFO : Model saved using code from earlier Gensim Version. Re-loading old model in a compatible way.
# 2019-01-07 14:26:23,350 : INFO : loading Word2Vec object from /Users/admin/gitprojects/trained_data/all/W2V
# 2019-01-07 14:26:48,514 : INFO : loaded /Users/admin/gitprojects/trained_data/all/W2V

# %%
print(w2v_np)
# Out:
# Word2Vec(vocab=562042, size=100, alpha=0.025)

# %% [markdown]
# ### Load FastText Wiki Model (Dutch)
# https://github.com/facebookresearch/fastText/blob/master/pretrained-vectors.md

# %%
print('\nLoading (FastText) Wikipedia Model')

# Creating the model
wiki = KeyedVectors.load_word2vec_format('/Volumes/AnneKroon/wiki.nl.vec')
# Out:
# 2019-01-07 15:11:32,077 : INFO : loading projection weights from /Volumes/AnneKroon/wiki.nl.vec
# Loading (FastText) Wikipedia Model
# 2019-01-07 15:17:56,240 : INFO : loaded (871022, 300) matrix from /Volumes/AnneKroon/wiki.nl.vec

# %%
print(len(wiki.vocab))
# Out:
# 871022

# %% [markdown]
#  # Intrinsic metrics
# ## 1. Word analogy method

# %% [markdown]
# Please find the complete analogy-testing file here: https://raw.githubusercontent.com/tmikolov/word2vec/master/questions-words.txt (in English)

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

def print_analogy_accuracy(model, questions_file):
    acc = model.wv.accuracy(questions_file)

    sem_correct = sum((len(acc[i]['correct']) for i in range(4)))
    sem_total = sum((len(acc[i]['correct']) + len(acc[i]['incorrect'])) for i in range(4))
    sem_acc = 100*float(sem_correct)/sem_total
    print('\nSemantic / Syntactics: {:d}/{:d}, Accuracy: {:.2f}%'.format(sem_correct, sem_total, sem_acc))

# %%
print('Accuracy for Word2Vec:')
print_analogy_accuracy(w2v_np, word_analogies_file)
# Out:
# Accuracy for Word2Vec:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:5: DeprecationWarning: Call to deprecated `accuracy` (Method will be removed in 4.0.0, use self.evaluate_word_analogies() instead).
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 2019-01-07 14:24:42,249 : INFO : capital-common-countries: 54.9% (168/306)
# 2019-01-07 14:24:44,013 : INFO : family: 71.6% (272/380)
# 2019-01-07 14:24:48,314 : INFO : gram3-comparative: 68.7% (558/812)
# 2019-01-07 14:24:48,316 : INFO : total: 66.6% (998/1498)
# Semantic / Syntactics: 1996/2996, Accuracy: 66.62%

# %%
print('Accuracy for FastText (Wiki):')
print_analogy_accuracy(wiki, word_analogies_file)
# Out:
# Accuracy for FastText (Wiki):
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:5: DeprecationWarning: Call to deprecated `accuracy` (Method will be removed in 4.0.0, use self.evaluate_word_analogies() instead).
# 2019-01-07 15:21:54,682 : INFO : precomputing L2-norms of word weight vectors
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 2019-01-07 15:23:14,843 : INFO : capital-common-countries: 92.1% (350/380)
# ...

# %% [markdown]
# ## 2. Word similarity task

# %%
def print_similarity_accuracy(model, similarity_file):
    acc = model.wv.evaluate_word_pairs(similarity_file)
    print('Pearson correlation coefficient: {:.2f}'.format(acc[0][0]))
    print('Spearman rank correlation coefficient: {:.2f}'.format(acc[1][0]))

# %%
print('\nWordSim-353 similarity word2vec')
print_similarity_accuracy(w2v_np, similarity_file)
# Out:
# WordSim-353 similarity
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 2019-01-07 15:37:39,664 : INFO : Skipping invalid line #2 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# 2019-01-07 15:37:39,705 : INFO : Skipping invalid line #7 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# 2019-01-07 15:37:39,742 : INFO : Skipping invalid line #13 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# 2019-01-07 15:37:39,804 : INFO : Skipping invalid line #18 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# 2019-01-07 15:37:39,819 : INFO : Skipping invalid line #24 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# ...

# %%
print('\nWordSim-353 similarity word2vec')
print_similarity_accuracy(wiki, similarity_file)
# Out:
# WordSim-353 similarity word2vec
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   from ipykernel import kernelapp as app
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 2019-01-07 15:38:12,449 : INFO : Skipping invalid line #2 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# 2019-01-07 15:38:12,465 : INFO : Skipping invalid line #7 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# 2019-01-07 15:38:12,489 : INFO : Skipping invalid line #13 in /Users/admin/awm/wordsim353/wordsim353_nl_kort.tsv
# ...

# %% [markdown]
# ## 3. Concept categorization
#
# ### Word2Vec

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.manifold import TSNE
import numpy as np

% matplotlib inline

keys = ['hond', 'olifant', 'roodborstje', 'kraai']

embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=7, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)


def tsne_plot_similar_words(title, labels, embedding_clusters, word_clusters, a, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=a, label=label)
        for i, word in enumerate(words):
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=8)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(True)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in w2v_np.most_similar(word, topn=30):
        words.append(similar_word)
        embeddings.append(w2v_np[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)

tsne_plot_similar_words('Similar words from LexisNexis newspaper data', keys, embeddings_en_2d, word_clusters, 0.7,
                        'similar_words.png')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:6: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ### FastText Wiki

# %%
embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in wiki.most_similar(word, topn=30):
        words.append(similar_word)
        embeddings.append(wiki[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)

tsne_plot_similar_words('Similar words from FastText Wiki data', keys, embeddings_en_2d, word_clusters, 0.7,
                        'similar_words.png')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

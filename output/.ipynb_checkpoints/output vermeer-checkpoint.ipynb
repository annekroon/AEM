# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_pickle('output_training_size_large_AEM_data_vermeer.pkl')

# %%
def rename_models(x):
    variable_name = x
    if x == 'w2v_model_nr_5_window_10_size_300_negsample_5':
        variable_name = 'w2v 5 (w = 10, d = 300, ns = 5)'
    if x =='w2v_model_nr_1_window_5_size_300_negsample_5':
        variable_name = 'w2v 1 (w = 5, d = 300, ns = 5)'
    if x == 'w2v_model_nr_8_window_47615_size_100_negsample_5':
        variable_name = 'w2v 8 (w = sentence, d = 100, ns = 5)'
    if x =='w2v_model_nr_11_window_47615_size_300_negsample_15':
        variable_name = 'w2v 11 (w = sentence, d = 300, ns = 15)'
    if x =='w2v_model_nr_4_window_10_size_100_negsample_5':
        variable_name = 'w2v 4 (w = 10, d = 100, ns = 5)'
    if x == 'w2v_model_nr_9_window_47615_size_300_negsample_5':
        variable_name = 'w2v 9 (w = sentence, d = 300, ns = 5)'
    if x == 'w2v_model_nr_3_window_5_size_300_negsample_15':
        variable_name = 'w2v 3 (w = 5, d = 300, ns = 15)'
    if x == 'w2v_model_nr_10_window_47615_size_100_negsample_15':
        variable_name = 'w2v 10 (w = sentence, d = 100, ns = 15)'
    if x == 'w2v_model_nr_7_window_10_size_300_negsample_15':
        variable_name = 'w2v 7 (w = 10, d = 100, ns = 15)'
    if x == 'w2v_model_nr_6_window_10_size_100_negsample_15':
        variable_name = 'w2v 6 (w = 10, d = 100, ns = 15)'
    if x == 'w2v_model_nr_2_window_5_size_100_negsample_15':
        variable_name = 'w2v 2 (w = 5, d = 100, ns = 15)'
    if x == 'w2v_model_nr_0_window_5_size_100_negsample_5':
        variable_name = 'w2v 0 (w = 5, d = 100, ns = 5)'
    if x == 'baseline':
        variable_name = 'baseline model'
    if x == 'wiki.nl.vec':
        variable_name = 'pre-trained 01: Wiki FastText'
    if x == 'cow-320.txt':
        variable_name = 'pre-trained 02: COW small'
    return variable_name

df['model'] = df['model'].map(rename_models)

df_n = pd.melt(df, id_vars = ['accuracy', 'train_size', 'model'], var_name='model classifier')
df_n['type'] = df_n['model'] + ' ~ ' + df_n['value'].astype(str)

# %%
df_n['n'] = 1
df_n.groupby('model').agg({'n' : sum, 'accuracy': np.mean})
# Out:
#                                          accuracy   n
# model
# baseline model                           0.698217  56
# cow-320.txt                              0.642470  56
# pre-trained 01: Wiki FastText            0.701860  56
# w2v 0 (w = 5, d = 100, ns = 5)           0.725998  56
# w2v 1 (w = 5, d = 300, ns = 5)           0.754405  56
# w2v 10 (w = sentence, d = 100, ns = 15)  0.741357  56
# w2v 11 (w = sentence, d = 300, ns = 15)  0.740411  56
# w2v 2 (w = 5, d = 100, ns = 15)          0.734080  56
# w2v 3 (w = 5, d = 300, ns = 15)          0.728095  56
# w2v 4 (w = 10, d = 100, ns = 5)          0.734343  56
# w2v 5 (w = 10, d = 300, ns = 5)          0.744596  56
# w2v 6 (w = 10, d = 100, ns = 15)         0.721092  56
# w2v 7 (w = 10, d = 100, ns = 15)         0.759643  56
# w2v 8 (w = sentence, d = 100, ns = 5)    0.741134  56
# w2v 9 (w = sentence, d = 300, ns = 5)    0.744456  56

# %%
df['type'] = df['model'] + ' ~ ' + df['classifier']

# %%
df_n = df.pivot(index = 'type', columns = 'train_size', values = 'accuracy')

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val > 0.80 else 'black'
    return 'color: %s' % color

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %% [markdown]
# # Results data Vermeer
#
# Red : value > .80. Yellow: highest value of column

# %%
df_n.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col5 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow0_col6 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col5 {
#             color:  red;
#             background-color:  yellow;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow1_col6 {
#             color:  red;
#             background-color:  yellow;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col5 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow2_col6 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col4 {
#             color:  red;
#             background-color:  yellow;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col5 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow3_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col5 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow4_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col5 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow5_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col3 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col4 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col5 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow6_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col5 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow7_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col3 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col4 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col5 {
#             color:  red;
#             background-color:  yellow;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow8_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col3 {
#             color:  red;
#             background-color:  yellow;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col4 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col5 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow9_col6 {
#             color:  red;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow10_col0 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow10_col1 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow10_col2 {
#             color:  black;
#             : ;
#         }    #T_19a02f18_afa5_11e9_bc3f_040091643bbbrow10_col3 {
#             color:  red

# %%
#f=open("Vermeer_Results.html","w")
#f.write(plot.render()) # df is the styled dataframe
#f.close()

# %%
def per_type(x):
    var = x
    if x.split('~')[-1] == ' w2v_ET ' and x.startswith('w2v'):
        var = 'w2v_ET_mean'
    elif x.split('~')[-1] == ' w2v_svm' and x.startswith('w2v'):
        var = 'w2v_svm_mean'
    return var

a = df
a['new_label'] = a['type'].apply(per_type)
a = a.groupby(['new_label', 'train_size']).agg(np.mean)
a = a.reset_index(level=[0,1])
a
# Out:
#                                   new_label  train_size  accuracy   f1score  \
# 0                       baseline model ~ ET          10  0.559551  0.401523
# 1                       baseline model ~ ET          40  0.571677  0.430940
# 2                       baseline model ~ ET         160  0.617859  0.531304
# 3                       baseline model ~ ET         640  0.698524  0.639651
# 4                       baseline model ~ ET        1000  0.727675  0.683869
# 5                       baseline model ~ ET        2500  0.740628  0.703733
# 6                       baseline model ~ ET        3386  0.752475  0.726286
# 7                      baseline model ~ svm          10  0.449655  0.470868
# 8                      baseline model ~ svm          40  0.656413  0.616275
# 9                      baseline model ~ svm         160  0.724594  0.682562
# 10                     baseline model ~ svm         640  0.784259  0.772183
# 11                     baseline model ~ svm        1000  0.779968  0.760157
# 12                     baseline model ~ svm        2500  0.820669  0.812023
# 13                     baseline model ~ svm        3386  0.891089  0.889880
# 14  pre-trained 01: Wiki FastText ~ w2v_ET           10  0.564730  0.507575
# 15  pre-trained 01: Wiki FastText ~ w2v_ET           40  0.648288  0.602009
# 16  pre-trained 01: Wiki FastText ~ w2v_ET          160  0.721888  0.681005
# 17  pre-trained 01: Wiki FastText ~ w2v_ET          640  0.779339  0.754239
# 18  pre-trained 01: Wiki FastText ~ w2v_ET         1000  0.786404  0.768962
# 19  pre-trained 01: Wiki FastText ~ w2v_ET         2500  0.798379  0.777784
# 20  pre-trained 01: Wiki FastText ~ w2v_ET         3386  0.782178  0.804087
# 21  pre-trained 01: Wiki FastText ~ w2v_svm          10  0.363061  0.370761
# 22  pre-trained 01: Wiki FastText ~ w2v_svm          40  0.425421  0.403837
# 23  pre-trained 01: Wiki FastText ~ w2v_svm         160  0.742634  0.705423
# 24  pre-trained 01: Wiki FastText ~ w2v_svm         640  0.791637  0.789034
# 25  pre-trained 01: Wiki FastText ~ w2v_svm        1000  0.824216  0.813372
# 26  pre-trained 01: Wiki FastText ~ w2v_svm        2500  0.776089  0.762835
# 27  pre-trained 01: Wiki FastText ~ w2v_svm        3386  0.821782  0.811126
# 28      pre-trained 02: COW small ~ w2v_ET           10  0.569908  0.500801
# 29      pre-trained 02: COW small ~ w2v_ET           40  0.638131  0.603683
# 30      pre-trained 02: COW small ~ w2v_ET          160  0.723993  0.675606
# 31      pre-trained 02: COW small ~ w2v_ET          640  0.777231  0.757040
# 32      pre-trained 02: COW small ~ w2v_ET         1000  0.783990  0.764263
# 33      pre-trained 02: COW small ~ w2v_ET         2500  0.799392  0.784776
# 34      pre-trained 02: COW small ~ w2v_ET         3386  0.801980  0.811109
# 35      pre-trained 02: COW small ~ w2v_svm          10  0.405351  0.389627
# 36      pre-trained 02: COW small ~ w2v_svm          40  0.124782  0.063877
# 37      pre-trained 02: COW small ~ w2v_svm         160  0.587793  0.459074
# 38      pre-trained 02: COW small ~ w2v_svm         640  0.764230  0.729912
# 39      pre-trained 02: COW small ~ w2v_svm        1000  0.381335  0.396137
# 40      pre-trained 02: COW small ~ w2v_svm        2500  0.775076  0.753360
# 41      pre-trained 02: COW small ~ w2v_svm        3386  0.861386  0.856942
# 42                              w2v_ET_mean          10  0.574295  0.536743
# 43                              w2v_ET_mean          40  0.678540  0.656849
# 44                              w2v_ET_mean         160  0.769919  0.743178
# 45                              w2v_ET_mean         640  0.799924  0.785042
# 46                              w2v_ET_mean        1000  0.801522  0.787224
# 47                              w2v_ET_mean        2500  0.814674  0.801721
# 48                              w2v_ET_mean        3386  0.846535  0.838368
# 49                             w2v_svm_mean          10  0.482859  0.492641
# 50                             w2v_svm_mean          40  0.626862  0.631237
# 51                             w2v_svm_mean         160  0.750301  0.745669
# 52                             w2v_svm_mean         640  0.798284  0.793433
# 53                             w2v_svm_mean        1000  0.784057  0.778648
# 54                             w2v_svm_mean        2500  0.785123  0.776902
# 55                             w2v_svm_mean        3386  0.834983  0.827524
#
#     precision    recall  type_model
# 0    0.313098  0.559551         7.0
# 1    0.655212  0.574289         8.0
# 2    0.692520  0.622369         9.0
# 3    0.730488  0.699578        10.0
# 4    0.762097  0.722848        11.0
# 5    0.782442  0.738602        12.0
# 6    0.762687  0.742574        13.0
# 7    0.585865  0.449655         0.0
# 8    0.626248  0.656413         1.0
# 9    0.719480  0.724594         2.0
# 10   0.775401  0.784259         3.0
# 11   0.780313  0.779968         4.0
# 12   0.814886  0.820669         5.0
# 13   0.896511  0.891089         6.0
# 14   0.625063  0.557250         7.0
# 15   0.725952  0.640743         8.0
# 16   0.771939  0.726398         9.0
# 17   0.785366  0.774772        10.0
# 18   0.792288  0.788415        11.0
# 19   0.811835  0.800405        12.0
# 20   0.823199  0.792079        13.0
# 21   0.699068  0.363061         0.0
# 22   0.622928  0.425421         1.0
# 23   0.782451  0.742634         2.0
# 24   0.804739  0.791637         3.0
# 25   0.820870  0.824216         4.0
# 26   0.813949  0.776089         5.0
# 27   0.855125  0.821782         6.0
# 28   0.569009  0.546605       147.0
# 29   0.726641  0.648288       148.0
# 30   0.752059  0.719182       149.0
# 31   0.786940  0.775474       150.0
# 32   0.788194  0.786404       151.0
# 33   0.808549  0.797366       152.0
# 34   0.819694  0.811881       153.0
# 35   0.489134  0.405351       140.0
# 36   0.079546  0.124782       141.0
# 37   0.430157  0.587793       142.0
# 38   0.708231  0.764230       143.0
# 39   0.856072  0.381335       144.0
# 40   0.784376  0.775076       145.0
# 41   0.867704  0.861386       146.0
# 42   0.581120  0.576141       101.5
# 43   0.750522  0.682482       102.5
# 44   0.769640  0.770169       103.5
# 45   0.798503  0.800158       104.5
# 46   0.801641  0.799645       105.5
# 47   0.818574  0.814505       106.5
# 48   0.848061  0.849835       107.5
# 49   0.614976  0.482859        94.5
# 50   0.729829  0.626862        95.5
# 51   0.772443  0.750301        96.5
# 52   0.805369  0.798284        97.5
# 53   0.798717  0.784057        98.5
# 54   0.795386  0.785123        99.5
# 55   0.840179  0.834983       100.5

# %%
def create_pointplot(df, x_value, y_value, hue=None,  col=None, row = None, wrap=None, size=8, aspect=1.5, title=""):
    p = sns.factorplot(x=x_value, y=y_value, kind='point',  hue=hue, row = row,
                       col=col, col_wrap=wrap, size=size, aspect=aspect, data=df, legend_out=False, palette=sns.color_palette('Set1'))
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    p.despine(left=True)
    for ax in p.axes.ravel():
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    return p

# %%
create_pointplot(a, 'train_size', 'accuracy', hue='new_label', size=10, aspect=1.5,
                 title="Accuracy across different classifiers")
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
create_pointplot(a, 'train_size', 'f1score', hue='new_label', size=10, aspect=1.5,
                 title="Accuracy across different classifiers")
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

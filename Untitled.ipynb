# %%
from inca import Inca

# %%
myinca = Inca()
# Out:
# INFO:INCA:Providing verbose output

# %%
myinca.database.list_doctypes()
# Out:
# {'': 1537,
#  'BBC Northern Ireland (www)': 3499,
#  'BBVA (corp)': 27,
#  'Banco Popular (corp)': 7,
#  'CDA (pol)': 4289,
#  'Der Freitag': 176024,
#  'DerTagesspiegel': 53681,
#  'Die Welt': 47064,
#  'GNF (corp)': 108,
#  'Groenlinks (pol)': 8277,
#  'Handelsblatt': 178208,
#  'Junge Freiheit': 34681,
#  'PVV (pol)': 335,
#  'PvdA (pol)': 4836,
#  'Red Electrica Corp (corp)': 71,
#  'SP (pol)': 16861,
#  'abc (www)': 34803,
#  'abnamro': 383,
#  'abnamro (corp)': 570,
#  'ad (print)': 1219265,
#  'ad (www)': 195139,
#  'anp': 2180672,
#  'arts & book review (print)': 996,
#  'asml (corp)': 92,
#  'banco popular (corp)': 20,
#  'bbc northern ireland (www)': 10621,
#  'bbva (corp)': 58,
#  'bd (www)': 153715,
#  'belangvanlimburg (www)': 20150,
#  'bndestem (www)': 135670,
#  'boskalis news (corp)': 13,
#  'boskalis press (corp)': 24,
#  'boskalisnews (corp)': 13,
#  'boskalispress (corp)': 88,
#  'btgroup (corp)': 169,
#  'cicero (www)': 1727,
# ...

# %% [markdown]
# # Prep the data of Burscher, Vliegenthart & De Vreese (2015) for classification
# An attempt to recode the data accordingly to the results presented [here](https://journals.sagepub.com/doi/abs/10.1177/0002716215569441?journalCode=anna)
#
# Anne Kroon, July 2019

# %% [markdown]
# # 1. read + recode the data

# %%
import pandas as pd

# %%
path_to_data ='/home/anne/tmpanne/'
df = pd.read_pickle(path_to_data + "news_dataset_annotated.pkl")

#len(pd.read_pickle('/home/anne/tmpanne/AEM_data/dataset_vermeer.pkl'))

# %%
def recode_cat(x):
    if x == " ":
        x = '99'
    return x

df['v9_major'] = df['v9_major'].map(recode_cat)

# V9 contains info on the 'main topics' : this is what we want i guess
df['main_topic'] = df['v9_major']
df['main_topic'] = df['main_topic'].astype(float)

# %%
''' some weird values occur in the column 'v9_major'. 
Consequently, I did my best to map the values to their 'major' category. 
I do not succeed in replicating the exact N per category as presented in Burscher et al. (Yet, it approaches it ..)''' 

d = {205: 20,
729: 7,
192 : 19,
1903 : 19,
18 : 99,
21 : 99,
23 : 99,
28 : 99,
29 : 99, 
30: 99,
31 : 99,
27  : 99,
32 : 99, 
24: 20,
205 : 20, 
185 : 18,
93: 9,
1609 : 16,
72 : 7,
1916 : 19,
729 : 7,
185 : 99,
93 : 9,
1609 : 16,
72 : 7,
1916 : 19,
993 : 99,
311: 99}

# %%
# apply dictionarly to recode

df['main_topic'] = df['main_topic'].map(d)
df.main_topic.fillna(df.v9_major, inplace =True)
df['main_topic'] = df['main_topic'].astype(int)
df['main_topic'] = df['main_topic'].astype(str)

# %%
print()
print("The number of unique labels is: {}".format(len(df['main_topic'].unique())))
# Out:
# The number of unique labels is: 19

# %%
def label_topic(row):
    if row['main_topic'] == '99':
        return 'Overige'
    if row['main_topic'] == '1':
        return 'Macro-economie en belastingen'
    if row['main_topic'] == '2':
        return 'Burgerrechten en vrijheden'
    if row['main_topic'] == '3':
        return 'Gezondheid'
    if row['main_topic'] == '4':
        return 'Landbouw en Visserij'
    if row['main_topic'] == '5':
        return 'Arbeid'
    if row['main_topic'] == '6':
        return 'Onderwijs'
    if row['main_topic'] == '7':
        return 'Milieu'
    if row['main_topic'] == '8':
        return 'Energiebeleid'
    if row['main_topic'] == '9':
        return 'Immigratie en integratie'
    if row['main_topic'] == '10':
        return 'Verkeer en vervoer'
    if row['main_topic'] == '11':
        return 'Unkown'
    if row['main_topic'] == '12':
        return 'Justitie, Rechtspraak, Criminaliteit'
    if row['main_topic'] == '13':
        return 'sociale Zaken'
    if row['main_topic'] == '14':
        return 'Gemeenschapsontwikkeling, huisvestingsbeleid en stedelijke planning'
    if row['main_topic'] == '15':
        return 'Ondernemingen, Bankwezen en binnenlandse handel '
    if row['main_topic'] == '16':
        return 'Defensie'
    if row['main_topic'] == '17':
        return 'Wetenschappelijk onderzoek, technologie en communicatie'
    if row['main_topic'] == '18':
        return 'Buitenlandse handel'
    if row['main_topic'] == '19':
        return 'Buitenlandse zaken en ontwikkelingssamenwerking'
    if row['main_topic'] == '20':
        return 'Functioneren democratie en openbaar bestuur'
    if row['main_topic'] == '21':
        return 'Ruimtelijke ordening, publiek natuur- en waterbeheer'
    if row['main_topic'] == '22':
        return 'Unkown 2'
    if row['main_topic'] == '23':
        return 'Kunst, cultuur en entertainment'
    if row['main_topic'] == '00':
        return 'Toegevoegde codes voor media'
    
#df.apply(lambda row: label_topic(row),axis=1)
df['main_topic_label'] = df.apply (lambda row: label_topic (row),axis=1)
df[['main_topic','main_topic_label']][0:5]
# Out:
#   main_topic main_topic_label
# 0         99          Overige
# 1         16         Defensie
# 2         16         Defensie
# 3          5           Arbeid
# 4          3       Gezondheid

# %%
df['main_topic'] = df['main_topic'].astype(int)
df['n'] = 1

# %% [markdown]
# # 2. Describe: N per label

# %%
agg = df.groupby(['main_topic', 'main_topic_label']).agg({'n': sum})
agg.sort_index()
agg.reset_index(level=[0,1], inplace=True)

# %%
agg
# Out:
#     main_topic                                   main_topic_label     n
# 0            1                      Macro-economie en belastingen   413
# 1            2                         Burgerrechten en vrijheden   327
# 2            3                                         Gezondheid   445
# 3            4                               Landbouw en Visserij   114
# 4            5                                             Arbeid   217
# 5            6                                          Onderwijs   188
# 6            7                                             Milieu   154
# 7            8                                      Energiebeleid    81
# 8            9                           Immigratie en integratie   151
# 9           10                                 Verkeer en vervoer   371
# 10          12               Justitie, Rechtspraak, Criminaliteit  1201
# 11          13                                      sociale Zaken   115
# 12          14  Gemeenschapsontwikkeling, huisvestingsbeleid e...   114
# 13          15   Ondernemingen, Bankwezen en binnenlandse handel    556
# 14          16                                           Defensie   394
# 15          17  Wetenschappelijk onderzoek, technologie en com...   427
# 16          19    Buitenlandse zaken en ontwikkelingssamenwerking  1109
# 17          20        Functioneren democratie en openbaar bestuur  1303
# 18          99                                            Overige  4879

# %%
print('The category "{}" (number: {}) occurs most often in the dataset: {}'
      .format(agg.loc[agg['n'].idxmax()]['main_topic_label'], agg.loc[agg['n'].idxmax()]['main_topic'],  agg['n'].max() ))

print()

print('The category "{}" (number: {}) occurs most often in the dataset: {}'
      .format(agg.loc[agg['n'].idxmin()]['main_topic_label'], agg.loc[agg['n'].idxmin()]['main_topic'],  agg['n'].min() ))
# Out:
# The category "Overige" (number: 99) occurs most often in the dataset: 4879
#
# The category "Energiebeleid" (number: 8) occurs most often in the dataset: 81

# %%
df['preprocessed_text'] = df.Processed_text.apply(', '.join)
len(df)
# Out:
#         Size WordCt                                              Title  \
# 0       2073    318  1899 of 1983 DOCUMENTS NRC Handelsblad January...
# 1      11159   1775  171 of 2386 DOCUMENTS De Telegraaf 6 december ...
# 2       1346    185  175 of 2386 DOCUMENTS De Telegraaf 5 december ...
# 3       2546    368  1142 of 1781 DOCUMENTS de Volkskrant May 1, 20...
# 4       6256    989  1189 of 1778 DOCUMENTS NRC Handelsblad May 7, ...
# 5       1442    210  181 of 2386 DOCUMENTS De Telegraaf 4 december ...
woorden  SECTION: VOORPAGINA; Blz. 1     3    12  2008
# 12550     LENGTH: 100 words     SECTION: Economie; Pg. 1     2     5  2001
# 12551     LENGTH: 593 words   SECTION: Voorpagina; Pg. 1     2     5  2001
# 12552     LENGTH: 303 words               SECTION: Pg. 1     3     7  2004
# 12553      LENGTH: 90 words       SECTION: boeken; Pg. 1     1     9  1996
# 12554     LENGTH: 398 words   SECTION: Voorpagina; Pg. 1     1     5  2001
# 12555   LENGTH: 263 woorden  SECTION: VOORPAGINA; Blz. 1     3    12  2008
# 12556      LENGTH: 95 words   SECTION: Voorpagina; Pg. 1     2     5  2001
# 12557     LENGTH: 416 words   SECTION: Voorpagina; Pg. 1     1     5  2001
# 12558     LENGTH: 522 words   SECTION: Voorpagina; Pg. 1     2     5  2001
#
#       day  ... V42 V43 V44 v9_major  \
# 0      16  ...                   99
# 1       6  ...   1   2   2       16
# 2       5  ...                   16
# 3       1  ...                    5
# 4       7  ...                    3
# 5       4  ...                   29
# 6       5  ...   2   2   2       21
# 7      28  ...   1   2   2       20
# 8      27  ...   2   1   2       20
# 9       4  ...   2   1   1        9
# 10     12  ...                   29
# 11     26  ...   1   2   2       12
# 12      3  ...                   23
# 13      3  ...   2   2   2       19
# 14     25  ...                   28
# 15      2  ...                   10
# 16      2  ...   2   2   2       12
# 17     23  ...                   23
# 18     30  ...   1   1   2        1
# 19      1  ...                   20
# 20      1  ...                    4
# 21     18  ...                   23
# 22     21  ...                    3
# 23     28  ...                   23
# 24     28  ...   2   1   2        1
# 25     29  ...   2   1   2        1
# 26     19  ...                   23
# 27     27  ...   1   2   2       20
# 28     25  ...                   23
# 29     18  ...   2   1   2        5
# ...    ..  ...  ..  ..  ..      ...
# 12529  23  ...   2   2   2        5
# 12530   9  ...                   15
# 12531  20  ...   2   1   2        5
# 12532  21  ...   2   1   1       20
# 12533  13  ...                    1
# 12534   9  ...   1   1   2       23
# 12535   8  ...   2   1   2       19
# 12536  19  ...   2   1   2       19
# 12537   7  ...   1   1   1       19
# 12538  11  ...   2   2   2       12
# 12539  17  ...   2   1   2        8
# 12540   5  ...   2   2   2        7
# 12541  12  ...   2   2   2        9
# 12542  10  ...   2   2   2       12
# 12543   4  ...                   10
# 12544  15  ...   1   2   2       20
# 12545  10  ...   1   1   2        3
# 12546  14  ...                   23
# 12547   4  ...   2   2   2        3
# 12548  12  ...   2   1   2       19
# 12549   8  ...   2   2   2       16
# 12550   4  ...                    5
# 12551   3  ...                   23
# 12552  26  ...                   12
# 12553  20  ...                   29
# 12554  11  ...   2   2   2        1
# 12555   7  ...                   29
# 12556   3  ...   2   2   2       23
# 12557   9  ...   2   2   2        1
# 12558   2  ...                    5
#
#                                                     text  \
# 0      De andere wereld van zondagmorgen Antropoloog ...
# 1      SAMENVATTINGDE SPEURTOCHT VAN EFRAIM ZUROFF na...
# 2      Vol verwachting kloppen de hartjes van onze st...
# 3      Wie als nieuwkomer bij een bedrijf denkt dat h...
# 4      In ziekenhuizen in Hengelo en Leeuwarden wordt...
# 5      Ajacied KlaasJan Huntelaar gisterochtend met z...
# 6      De Poolse gemeente OswieCim houdt in juli een ...
# 7      Het politieke leven van staatssecretaris H van...
# 12556  BERLIJN  De vrouw van Hitlers propagandaminist...
# 12557  De Rabobank verzet zich als enige grote bank i...
# 12558  Steeds meer verpleegkundigen werken naast hun ...
#
#                                           Processed_text main_topic  \
# 0      [wereld, zondagmorg, antropolog, dr, mattijs, ...         99
# 1      [samenvattingd, speurtocht, efraim, zuroff, na...         16
# 2      [vol, verwacht, klopp, hartjes, onz, stoer, ma...         16
# 3      [nieuwkomer, bedrijf, denkt, flink, salaris, g...          5
# 4      [ziekenhuiz, hengelo, leeuward, vandag, gestaa...          3
# 5      [ajacied, klaasjan, huntelar, gisterocht, vrie...         99
# 6      [pol, gemeent, oswiecim, houdt, juli, referend...         99
# 7      [politiek, lev, staatssecretaris, hof, vvd, zi...         20
# 8      [brit, over, ieder, pasgebor, baby, kraamprese...         20
# 9      [vermoed, zon, noordkoreaan, leider, kim, jong...          9
# 10     [kop, gonzalez, geeft, columbian, red, vreugde...         99
# 11     [open, ministerie, stelt, strafrecht, onderzoe...         12
# 12     [koningin, beatrix, hoogsteig, person, hangt, ...         99
# 13     [amerikan, ministerie, defensie, gister, all, ...         19
# 14     [rio, janeiro, noord, brazilie, boer, familie,...         99
# 15     [busbedrijf, connexxion, koninginnedag, tijden...         10
# 16     [samenvattingdor, mariek, ess, delft, dinsdag,...         12
# 17     [hoofdrol, vertolk, nieuw, opera, internationa...         99
# 18     [war, haald, kabinet, inen, snel, 8, miljard, ...          1
# 19     [gestrand, bangkok, duikt, inen, sinterklas, a...         20
# 20     [onz, correspondentwagen, maandagpopulair, maa...          4
# 21     [mens, vloer, won, 19deeeuw, da, costabuurt, a...         99
# 22     [amsterdam, aantal, vrouw, tijden, kort, beval...          3
# 23     [elsbeth, etty, volgend, wek, vakantie, column...         99
# 24     [kabinet, vannacht, akkoord, bereikt, begrot, ...          1
# 25     [samenvattingdor, manno, den, berg, herman, st...          1
# 26     [zit, sind, twee, dag, wer, thuis, etag, amste...         99
# 27     [minister, grav, defensie, gister, eind, kamer...         20
# 28     [highlightcd, tweedor, jan, colijndoetinchem, ...         99
# 29     [nederland, spoorweg, gan, lon, inhoud, conduc...          5
# ...                                                  ...        ...
# 12529  [uitzendconcern, randstad, gat, komend, wek, t...          5
# 12530  [precies, period, abn, amro, eerst, ker, kwart...         15
# 12531  [rotterdam, 20, sept, nieuw, hooglerar, moet, ...          5
# 12532  [kroonprin, willemalexander, maxima, trouw, 2,...         20
# 12533  [samenvattingvan, onz, financiel, redactie, am...          1
# 12534  [redacteur, amsterdam, zender, at5, voel, piet...         99
# 12535  [secretarisgeneral, navo, georg, robertson, ma...         19
# 12536  [amerikan, president, bush, elk, versoepel, ec...         19
# 12537  [aardedonker, onderan, keldertrap, kijk, angst...         19
# 12538  [samenvattingdor, bert, huisjes, amsterdam, do...         12
# 12539  [verenigd, stat, geconfronteerd, ernstigst, en...          8
# 12540  [genetisch, gemanipuleerd, maissoort, starlink...          7
# 12541  [kop, asielzoeker, verwijdercentrum, duik, vak...          9
# 12547                                        Gezondheid  1
# 12548   Buitenlandse zaken en ontwikkelingssamenwerking  1
# 12549                                          Defensie  1
# 12550                                            Arbeid  1
# 12551                                           Overige  1
# 12552              Justitie, Rechtspraak, Criminaliteit  1
# 12553                                           Overige  1
# 12554                     Macro-economie en belastingen  1
# 12555                                           Overige  1
# 12556                                           Overige  1
# 12557                     Macro-economie en belastingen  1
# 12558                                            Arbeid  1
#
#                                        preprocessed_text
# 0      wereld, zondagmorg, antropolog, dr, mattijs, p...
# 1      samenvattingd, speurtocht, efraim, zuroff, naz...
# 2      vol, verwacht, klopp, hartjes, onz, stoer, man...
# 3      nieuwkomer, bedrijf, denkt, flink, salaris, ge...
# 4      ziekenhuiz, hengelo, leeuward, vandag, gestaak...
# 5      ajacied, klaasjan, huntelar, gisterocht, vrien...
# 6      pol, gemeent, oswiecim, houdt, juli, referendu...
# 7      politiek, lev, staatssecretaris, hof, vvd, zij...
# 8      brit, over, ieder, pasgebor, baby, kraampresen...
# 9      vermoed, zon, noordkoreaan, leider, kim, jongi...
# 10     kop, gonzalez, geeft, columbian, red, vreugdet...
# 11     open, ministerie, stelt, strafrecht, onderzoek...
# 12     koningin, beatrix, hoogsteig, person, hangt, b...
# 13     amerikan, ministerie, defensie, gister, all, m...
# 14     rio, janeiro, noord, brazilie, boer, familie, ...
# 15     busbedrijf, connexxion, koninginnedag, tijden,...
# 16     samenvattingdor, mariek, ess, delft, dinsdag, ...
# 17     hoofdrol, vertolk, nieuw, opera, international...
# 18     war, haald, kabinet, inen, snel, 8, miljard, e...
# 19     gestrand, bangkok, duikt, inen, sinterklas, aa...
# 20     onz, correspondentwagen, maandagpopulair, maal...
# 21     mens, vloer, won, 19deeeuw, da, costabuurt, am...
# 22     amsterdam, aantal, vrouw, tijden, kort, bevall...
# 23     elsbeth, etty, volgend, wek, vakantie, column,...
# 24     kabinet, vannacht, akkoord, bereikt, begrot, 2...
# 25     samenvattingdor, manno, den, berg, herman, sta...
# 26     zit, sind, twee, dag, wer, thuis, etag, amster...
# 27     minister, grav, defensie, gister, eind, kamerd...
# 28     highlightcd, tweedor, jan, colijndoetinchem, z...
# 29     nederland, spoorweg, gan, lon, inhoud, conduct...
# ...                                                  ...
# 12529  uitzendconcern, randstad, gat, komend, wek, tw...
# 12530  precies, period, abn, amro, eerst, ker, kwarta...
# 12531  rotterdam, 20, sept, nieuw, hooglerar, moet, l...
# 12532  kroonprin, willemalexander, maxima, trouw, 2, ...
# 12533  samenvattingvan, onz, financiel, redactie, ams...
# 12534  redacteur, amsterdam, zender, at5, voel, pietj...
# 12535  secretarisgeneral, navo, georg, robertson, mac...
# 12536  amerikan, president, bush, elk, versoepel, eco...
# 12537  aardedonker, onderan, keldertrap, kijk, angsti...
# 12538  samenvattingdor, bert, huisjes, amsterdam, don...
# 12539  verenigd, stat, geconfronteerd, ernstigst, ene...
# 12540  genetisch, gemanipuleerd, maissoort, starlink,...
# 12541  kop, asielzoeker, verwijdercentrum, duik, vak,...
# 12542  wit, kist, bedekt, wit, bloem, kaart, emotione...
# 12543  foto, raymond, rutting, volkskrant, amsterdam,...
# 12544  eerst, toesprak, royal, verkiezingsoverwinn, d...
# 12545  jenny, zijdenamsterdam, woensdagvrijwel, hel, ...
# 12546  aantal, dagblad, per, huishoud, afgelop, derti...
# 12547  minister, borst, volksgezond, woensdag, duidel...
# 12548  controversiel, berlusconi, belangrijkst, bindm...
# 12549  roy, klopperd, helder, maandagd, konink, marin...
# 12550  new, york, verlies, ban, verenigd, stat, afgel...
# 12551  gerard, rev, james, joyc, lewis, carol, astrid...
# 12552  highlightjustitie, vond, onvoldo, bewijsvan, o...
# 12553  sao, paulo, 20, sept, oostenrijk, daviscupploe...
# 12554  consumentenprijz, nederland, april, jar, geste...
# 12555  ottman, bakkal, rust, ingevall, schiet, psv, b...
# 12556  berlijn, vrouw, hitler, propagandaminister, jo...
# 12557  rabobank, verzet, enig, grot, bank, nederland,...
# 12558  sted, verpleegkund, werk, naast, ban, ziekenhu...
#
# [12559 rows x 62 columns]

# %%
df_subset = df[['preprocessed_text', 'main_topic', 'main_topic_label']]
df_subset.rename(columns={'preprocessed_text' : 'text', 'main_topic' : 'topic'}, inplace = True)
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_subset.to_pickle('/home/anne/tmpanne/AEM_data/dataset_burscher.pkl')

# %% [markdown]
# # 3. Try out some classifiers

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import SGDClassifier

X_train, X_test, y_train, y_test = train_test_split(df['Joined'], df['main_topic'], test_size=0.2, random_state=42)

pa = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', SGDClassifier(loss='hinge', penalty='elasticnet', tol=1e-4, alpha=1e-6, max_iter=5000, random_state=42))
                            ])
pa.fit(X_train, y_train)
preds = pa.predict(X_test)

# %%
print(classification_report(y_test, preds))

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test, preds))

from sklearn.metrics import precision_recall_fscore_support as score

precision,recall,fscore,support=score(y_test, preds, average='weighted')
print ('Precision : {}'.format(precision))
print ('Recall    : {}'.format(recall))
print( 'F-score   : {}'.format(fscore))
print( 'Support   : {}'.format(support))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.61      0.33      0.43        90
#          10       0.57      0.67      0.62        86
#          12       0.62      0.66      0.64       248
#          13       0.67      0.10      0.17        21
#          14       0.70      0.28      0.40        25
#          15       0.54      0.66      0.60        92
#          16       0.54      0.40      0.46        81
#          17       0.49      0.44      0.47        81
#          19       0.56      0.70      0.62       242
#           2       0.27      0.08      0.13        71
#          20       0.55      0.64      0.59       251
#           3       0.54      0.65      0.59        79
#           4       0.55      0.81      0.65        21
#           5       0.30      0.35      0.32        34
#           6       0.74      0.76      0.75        37
#           7       0.45      0.13      0.20        39
#           8       0.64      0.50      0.56        14
#           9       0.68      0.66      0.67        32
#          99       0.80      0.79      0.79       968
#
# avg / total       0.65      0.65      0.64      2512
#
# Precision : 0.6473170211554333
# Recall    : 0.6508757961783439
# F-score   : 0.6396840566229829
# Support   : None
